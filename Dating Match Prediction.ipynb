# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/predict-online-dating-matches-dataset/Online_Dating_Behavior_Dataset.csv

# %%
import pandas as pd 
import numpy as np 
from sklearn.metrics import accuracy_score, mean_squared_error, confusion_matrix, classification_report

# %%
# Read File
date_aset = pd.read_csv('/kaggle/input/predict-online-dating-matches-dataset/Online_Dating_Behavior_Dataset.csv')

# %%
date_aset.describe()
# Out:
#            Gender  PurchasedVIP        Income     Children          Age  \
# count  1000.00000   1000.000000   1000.000000  1000.000000  1000.000000
# mean      0.51000      0.474000  50988.447000     0.978000    34.616000
# std       0.50015      0.499573   9889.336141     0.997251     9.147799
# min       0.00000      0.000000  20786.000000     0.000000    18.000000
# 25%       0.00000      0.000000  44358.500000     0.000000    27.000000
# 50%       1.00000      0.000000  50841.500000     1.000000    35.000000
# 75%       1.00000      1.000000  57396.000000     2.000000    43.000000
# max       1.00000      1.000000  81931.000000     3.000000    49.000000
#
#        Attractiveness     Matches
# count     1000.000000  1000.00000
# mean         5.624000    76.05000
# std          2.824288    52.71315
# min          1.000000     0.00000
# 25%          3.000000     0.00000
# 50%          6.000000    70.00000
# 75%          8.000000   120.00000
# max         10.000000   160.00000

# %% [markdown]
# *From the description, it seems that all of the column values all have numerical values, therefore no encoding is needed. The standard deviation for the income seems a bit high so we need to use some standard scaler feature scaling technique and a min-max scaling for Matches which can help the model to learn better.*

# %%
date_aset["Matches"].unique()
# Out:
# array([ 70, 130,   0, 110, 140, 120, 150, 160, 100,  90,  80])

# %% [markdown]
# *We'll have to use a regression model for this one*

# %%
# Check for any columns with null type that needs to be imputed
date_aset.isnull().any()
# Out:
# Gender            False
# PurchasedVIP      False
# Income            False
# Children          False
# Age               False
# Attractiveness    False
# Matches           False
# dtype: bool

# %%
# Check for any duplicates 
duplicates = date_aset.duplicated()
duplicated_rows = date_aset[duplicates]
duplicates.sum()
# Out:
# 0

# %% [markdown]
# # Create dataset

# %%
# Define features and target variables 
features = ["Gender", "PurchasedVIP", "Income", "Children", "Age", "Attractiveness"]
target = ["Matches"]

# %%
# Dataset
X = date_aset[features]
y = date_aset[target]
labels = date_aset.columns.to_numpy() # Save labels for later

# %% [markdown]
# # Splitting Dataset

# %%
from sklearn.model_selection import train_test_split

# %%
RANDOM_STATE = 1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = RANDOM_STATE)

# %%
print(f"{X_train.shape} {y_train.shape}")
print(f"{X_test.shape} {y_test.shape}")
# Out:
# (600, 6) (600, 1)
# (400, 6) (400, 1)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler() 
scaler.fit(X_train)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns = labels[:-1])
X_train_scaled.describe()
# Out:
#              Gender  PurchasedVIP        Income      Children           Age  \
# count  6.000000e+02  6.000000e+02  6.000000e+02  6.000000e+02  6.000000e+02
# mean   1.051011e-16 -9.769963e-17  3.212245e-16 -2.664535e-17 -6.513308e-17
# std    1.000834e+00  1.000834e+00  1.000834e+00  1.000834e+00  1.000834e+00
# min   -1.027032e+00 -9.137080e-01 -2.966589e+00 -1.013525e+00 -1.858921e+00
# 25%   -1.027032e+00 -9.137080e-01 -6.461503e-01 -1.013525e+00 -8.609915e-01
# 50%    9.736796e-01 -9.137080e-01 -1.205916e-02 -3.367194e-03  2.605705e-02
# 75%    9.736796e-01  1.094442e+00  6.046105e-01  1.006791e+00  9.131056e-01
# max    9.736796e-01  1.094442e+00  2.533881e+00  2.016949e+00  1.578392e+00
#
#        Attractiveness
# count    6.000000e+02
# mean    -1.480297e-18
# std      1.000834e+00
# min     -1.598354e+00
# 25%     -9.029137e-01
# 50%      1.402472e-01
# 75%      8.356878e-01
# max      1.531128e+00

# %%
X_test_scaled = pd.DataFrame(X_test_scaled, columns = labels[:-1])
X_test_scaled.describe()
# Out:
#              Gender  PurchasedVIP        Income      Children           Age  \
# count  4.000000e+02  4.000000e+02  4.000000e+02  4.000000e+02  4.000000e+02
# mean   1.110223e-17  1.776357e-17 -1.332268e-16  3.552714e-17  1.953993e-16
# std    1.001252e+00  1.001252e+00  1.001252e+00  1.001252e+00  1.001252e+00
# min   -1.010051e+00 -1.005013e+00 -3.162272e+00 -9.346874e-01 -1.758386e+00
# 25%   -1.010051e+00 -1.005013e+00 -7.241434e-01 -9.346874e-01 -7.929766e-01
# 50%    9.900495e-01  9.950124e-01  5.557212e-03  5.966090e-02 -4.210258e-02
# 75%    9.900495e-01  9.950124e-01  6.837093e-01  1.054009e+00  8.160391e-01
# max    9.900495e-01  9.950124e-01  3.125875e+00  2.048357e+00  1.566913e+00
#
#        Attractiveness
# count    4.000000e+02
# mean    -4.440892e-18
# std      1.001252e+00
# min     -1.701968e+00
# 25%     -9.722927e-01
# 50%      1.222207e-01
# 75%      8.518962e-01
# max      1.581572e+00

# %% [markdown]
# *We now see our standard deviation for our datasets are 1*

# %% [markdown]
# # Creating and Training the Model

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
param_grid = {
    "n_estimators": [50, 100, 200], 
    "max_depth": [10, 25, 50, 75],
    "min_samples_split": [2, 10, 50], 
    "min_samples_leaf": [1, 2, 4, 8]
}

# %%
# Hyperparamater Tuning 
from sklearn.model_selection import GridSearchCV 

grid_search = GridSearchCV(
    estimator=RandomForestRegressor(),  
    param_grid=param_grid,              
    cv=3,                               # Number of cross-validation folds
    scoring='neg_mean_squared_error',   # Scoring method
    n_jobs=-1,                          # Use all available cores
    verbose=3                           # Verbosity level
)

# %%
grid_search.fit(X_train_scaled, y_train.values.ravel())
# Out:
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.8s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.4s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.8s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=50, n_estimators=50;, score=-18.583 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=50, n_estimators=100;, score=-18.782 total time=   0.4s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=50, n_estimators=200;, score=-17.231 total time=   0.7s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.4s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.5s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=50, n_estimators=50;, score=-18.177 total time=   0.2s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=50, n_estimators=50;, score=-17.222 total time=   0.2s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=50, n_estimators=100;, score=-17.760 total time=   0.4s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=50, n_estimators=200;, score=-14.979 total time=   0.6s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.6s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=50, n_estimators=100;, score=-16.741 total time=   0.3s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=50, n_estimators=200;, score=-16.961 total time=   0.6s
# [CV 2/3] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=-0.046 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=200;, score=-0.295 total time=   0.6s
# [CV 1/3] END max_depth=10, min_samples_leaf=8, min_samples_split=10, n_estimators=200;, score=-0.359 total time=   0.7s
# [CV 1/3] END max_depth=10, min_samples_leaf=8, min_samples_split=50, n_estimators=100;, score=-17.280 total time=   0.4s
# [CV 2/3] END max_depth=10, min_samples_leaf=8, min_samples_split=50, n_estimators=200;, score=-16.505 total time=   0.6s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=50, n_estimators=200;, score=-18.256 total time=   0.6s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=50, n_estimators=50;, score=-16.443 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=50, n_estimators=50;, score=-16.994 total time=   0.2s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=50, n_estimators=50;, score=-17.813 total time=   0.2s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=50, n_estimators=100;, score=-18.369 total time=   0.3s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=-0.003 total time=   0.2s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=50, n_estimators=50;, score=-17.770 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=50, n_estimators=50;, score=-17.457 total time=   0.2s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=50, n_estimators=50;, score=-17.902 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=50, n_estimators=100;, score=-13.526 total time=   0.5s
# [CV 1/3] END max_depth=25, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=-0.443 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=-0.039 total time=   0.2s
# [CV 3/3] END max_depth=25, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=-0.156 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=-0.026 total time=   0.6s
# [CV 1/3] END max_depth=25, min_samples_leaf=8, min_samples_split=10, n_estimators=50;, score=-0.398 total time=   0.4s
# [CV 2/3] END max_depth=25, min_samples_leaf=8, min_samples_split=10, n_estimators=50;, score=-0.048 total time=   0.4s
# [CV 1/3] END max_depth=25, min_samples_leaf=8, min_samples_split=10, n_estimators=200;, score=-0.394 total time=   0.7s
# [CV 1/3] END max_depth=25, min_samples_leaf=8, min_samples_split=50, n_estimators=100;, score=-16.621 total time=   0.3s
# [CV 2/3] END max_depth=25, min_samples_leaf=8, min_samples_split=50, n_estimators=200;, score=-16.179 total time=   0.6s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=50, n_estimators=50;, score=-17.817 total time=   0.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=50, n_estimators=100;, score=-16.156 total time=   0.3s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=50, n_estimators=200;, score=-17.045 total time=   0.6s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.6s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   1.1s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   1.0s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=50, n_estimators=100;, score=-18.277 total time=   0.4s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=50, n_estimators=200;, score=-14.919 total time=   0.8s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   1.0s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.4s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=50, n_estimators=100;, score=-18.653 total time=   0.3s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=-0.002 total time=   0.2s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=50, n_estimators=100;, score=-18.030 total time=   0.3s
# [CV 1/3] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=-0.384 total time=   0.2s
# [CV 2/3] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=-0.053 total time=   0.2s
# [CV 3/3] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=-0.071 total time=   0.2s
# [CV 3/3] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=-0.121 total time=   0.3s
# [CV 1/3] END max_depth=10, min_samples_leaf=8, min_samples_split=10, n_estimators=50;, score=-0.213 total time=   0.2s
# [CV 2/3] END max_depth=10, min_samples_leaf=8, min_samples_split=10, n_estimators=50;, score=-0.126 total time=   0.2s
# [CV 3/3] END max_depth=10, min_samples_leaf=8, min_samples_split=10, n_estimators=50;, score=-0.280 total time=   0.2s
# [CV 2/3] END max_depth=10, min_samples_leaf=8, min_samples_split=10, n_estimators=100;, score=-0.036 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=8, min_samples_split=10, n_estimators=200;, score=-0.099 total time=   0.7s
# [CV 1/3] END max_depth=10, min_samples_leaf=8, min_samples_split=50, n_estimators=200;, score=-18.895 total time=   0.7s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.6s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=50, n_estimators=50;, score=-18.205 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=50, n_estimators=50;, score=-15.592 total time=   0.2s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=50, n_estimators=50;, score=-17.773 total time=   0.2s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=50, n_estimators=100;, score=-18.554 total time=   0.3s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.6s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=50, n_estimators=100;, score=-16.711 total time=   0.3s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=50, n_estimators=200;, score=-16.434 total time=   0.6s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=50, n_estimators=100;, score=-19.712 total time=   0.4s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=50, n_estimators=200;, score=-16.750 total time=   0.8s
# [CV 1/3] END max_depth=25, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=-0.499 total time=   0.4s
# [CV 3/3] END max_depth=25, min_samples_leaf=8, min_samples_split=2, n_estimators=200;, score=-0.160 total time=   0.8s
# [CV 2/3] END max_depth=25, min_samples_leaf=8, min_samples_split=10, n_estimators=100;, score=-0.016 total time=   0.4s
# [CV 1/3] END max_depth=25, min_samples_leaf=8, min_samples_split=50, n_estimators=50;, score=-16.824 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=8, min_samples_split=50, n_estimators=50;, score=-21.134 total time=   0.2s
# [CV 3/3] END max_depth=25, min_samples_leaf=8, min_samples_split=50, n_estimators=50;, score=-18.774 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=8, min_samples_split=50, n_estimators=100;, score=-16.331 total time=   0.3s
# [CV 3/3] END max_depth=25, min_samples_leaf=8, min_samples_split=50, n_estimators=200;, score=-16.002 total time=   0.6s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.6s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=50, n_estimators=200;, score=-17.789 total time=   0.7s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 2/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=50, n_estimators=50;, score=-18.645 total time=   0.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=2, min_samples_split=50, n_estimators=50;, score=-16.124 total time=   0.2s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=50, n_estimators=100;, score=-18.305 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.3s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.4s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.3s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.6s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=50, n_estimators=50;, score=-17.101 total time=   0.2s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=50, n_estimators=50;, score=-15.899 total time=   0.3s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=50, n_estimators=100;, score=-15.685 total time=   0.5s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.4s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=50, n_estimators=50;, score=-17.824 total time=   0.2s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=50, n_estimators=100;, score=-15.514 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=50, n_estimators=200;, score=-17.418 total time=   0.7s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=-0.002 total time=   0.2s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=50, n_estimators=50;, score=-17.396 total time=   0.2s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=50, n_estimators=50;, score=-16.230 total time=   0.2s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=50, n_estimators=50;, score=-17.132 total time=   0.2s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=50, n_estimators=100;, score=-14.239 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=50, n_estimators=200;, score=-16.617 total time=   0.6s
# [CV 1/3] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=200;, score=-0.298 total time=   0.6s
# [CV 1/3] END max_depth=10, min_samples_leaf=8, min_samples_split=10, n_estimators=100;, score=-0.335 total time=   0.3s
# [CV 2/3] END max_depth=10, min_samples_leaf=8, min_samples_split=10, n_estimators=200;, score=-0.033 total time=   0.7s
# [CV 2/3] END max_depth=10, min_samples_leaf=8, min_samples_split=50, n_estimators=100;, score=-17.932 total time=   0.4s
# [CV 3/3] END max_depth=10, min_samples_leaf=8, min_samples_split=50, n_estimators=200;, score=-18.507 total time=   0.6s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.6s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=50, n_estimators=100;, score=-14.961 total time=   0.3s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=50, n_estimators=200;, score=-18.588 total time=   0.6s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=50, n_estimators=100;, score=-15.601 total time=   0.3s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=50, n_estimators=200;, score=-17.553 total time=   0.6s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=50, n_estimators=100;, score=-17.516 total time=   0.4s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=50, n_estimators=200;, score=-17.484 total time=   0.9s
# [CV 1/3] END max_depth=25, min_samples_leaf=8, min_samples_split=2, n_estimators=200;, score=-0.294 total time=   0.9s
# [CV 1/3] END max_depth=25, min_samples_leaf=8, min_samples_split=10, n_estimators=100;, score=-0.391 total time=   0.5s
# [CV 3/3] END max_depth=25, min_samples_leaf=8, min_samples_split=10, n_estimators=200;, score=-0.125 total time=   0.6s
# [CV 1/3] END max_depth=25, min_samples_leaf=8, min_samples_split=50, n_estimators=200;, score=-17.226 total time=   0.6s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=50, n_estimators=50;, score=-16.803 total time=   0.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=50, n_estimators=50;, score=-16.460 total time=   0.2s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=50, n_estimators=100;, score=-16.857 total time=   0.3s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=50, n_estimators=200;, score=-16.114 total time=   0.6s
# [CV 2/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=50, n_estimators=50;, score=-18.312 total time=   0.2s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=50, n_estimators=100;, score=-15.767 total time=   0.3s
# [CV 1/3] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 1/3] END max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.8s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.6s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   1.0s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=50, n_estimators=200;, score=-17.440 total time=   0.9s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.4s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.4s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=50, n_estimators=200;, score=-17.113 total time=   0.6s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=50, n_estimators=200;, score=-18.018 total time=   0.6s
# [CV 1/3] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=-0.331 total time=   0.3s
# [CV 2/3] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=200;, score=-0.028 total time=   0.6s
# [CV 3/3] END max_depth=10, min_samples_leaf=8, min_samples_split=10, n_estimators=100;, score=-0.235 total time=   0.3s
# [CV 1/3] END max_depth=10, min_samples_leaf=8, min_samples_split=50, n_estimators=50;, score=-15.536 total time=   0.2s
# [CV 2/3] END max_depth=10, min_samples_leaf=8, min_samples_split=50, n_estimators=50;, score=-16.348 total time=   0.2s
# [CV 3/3] END max_depth=10, min_samples_leaf=8, min_samples_split=50, n_estimators=50;, score=-18.362 total time=   0.2s
# [CV 3/3] END max_depth=10, min_samples_leaf=8, min_samples_split=50, n_estimators=100;, score=-17.607 total time=   0.4s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.6s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=50, n_estimators=100;, score=-16.934 total time=   0.3s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=50, n_estimators=200;, score=-16.629 total time=   0.6s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.6s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=50, n_estimators=200;, score=-18.040 total time=   0.6s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.4s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=50, n_estimators=200;, score=-17.795 total time=   1.0s
# [CV 3/3] END max_depth=25, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=-0.089 total time=   0.3s
# [CV 2/3] END max_depth=25, min_samples_leaf=8, min_samples_split=2, n_estimators=200;, score=-0.041 total time=   0.7s
# [CV 3/3] END max_depth=25, min_samples_leaf=8, min_samples_split=10, n_estimators=50;, score=-0.062 total time=   0.2s
# [CV 3/3] END max_depth=25, min_samples_leaf=8, min_samples_split=10, n_estimators=100;, score=-0.136 total time=   0.4s
# [CV 2/3] END max_depth=25, min_samples_leaf=8, min_samples_split=10, n_estimators=200;, score=-0.021 total time=   0.7s
# [CV 3/3] END max_depth=25, min_samples_leaf=8, min_samples_split=50, n_estimators=100;, score=-16.014 total time=   0.3s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=50, n_estimators=100;, score=-17.984 total time=   0.3s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=-0.000 total time=   0.3s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-0.000 total time=   0.7s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=50, n_estimators=200;, score=-17.913 total time=   0.6s
# [CV 1/3] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=-0.002 total time=   0.3s
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [10, 25, 50, 75],
#                          'min_samples_leaf': [1, 2, 4, 8],
#                          'min_samples_split': [2, 10, 50],
#                          'n_estimators': [50, 100, 200]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
print(f"{-grid_search.best_score_:.6f}")
# Out:
# -0.000000

# %%
grid_search.best_params_
# Out:
# {'max_depth': 10,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 50}

# %% [markdown]
# # Evaluating the Model

# %%
best_params = grid_search.best_params_

# %%
best_model = RandomForestRegressor(**best_params)

# %%
best_model.fit(X_train_scaled, y_train.values.ravel())
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=50)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Evaluate on the cross validation set 
y_test_pred = best_model.predict(X_test_scaled.to_numpy())
mse = mean_squared_error(y_test, y_test_pred)
r2 = r2_score(y_test, y_test_pred)

print(f"Mean Squared Error (MSE) on Test Set: {mse:.6f}")
print(f"R-squared Score (R2) on Test Set: {r2:.6f}")
# Out:
# Mean Squared Error (MSE) on Test Set: 0.000000
# R-squared Score (R2) on Test Set: 1.000000
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
# Check for Bias and Variance (Overfitting)
y_train_pred = best_model.predict(X_train_scaled.to_numpy())
mse_train = mean_squared_error(y_train, y_train_pred)
print(f"Training Set MSE: {mse_train:.6f} vs. Test Set MSE: {mse:.6f}")
# Out:
# Training Set MSE: 0.000000 vs. Test Set MSE: 0.000000
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# *Seems like we have a remarkable seemingly 100% accuracy here. Let's do a cross validation score test across the subsets of our data*

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
# Perform cross-validation
cv_scores = cross_val_score(best_model, X, y.values.ravel(), cv=5, scoring='neg_mean_squared_error')

# Convert negative MSE to positive
cv_scores = -cv_scores

print(f"Cross-validated MSE scores: {cv_scores}")
print(f"Mean cross-validated MSE: {cv_scores.mean():.6f}")
print(f"Standard deviation of cross-validated MSE: {cv_scores.std():.6f}")
# Out:
# Cross-validated MSE scores: [0. 0. 0. 0. 0.]
# Mean cross-validated MSE: 0.000000
# Standard deviation of cross-validated MSE: 0.000000
